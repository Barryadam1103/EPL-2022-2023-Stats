# %% [markdown]
# # EPL 2022-2023 Home Stats

# %%
import pandas as pd
data = pd.read_csv('2023_home_teams_stats.csv')
data.head()
# Out:
#    fixture id  Home team id  Home team name  Shots on Goal  Shots off Goal  \
# 0      867946            52  Crystal Palace            2.0             2.0
# 1      867947            36          Fulham            3.0             2.0
# 2      867948            35     Bournemouth            3.0             2.0
# 3      867949            63           Leeds            4.0             5.0
# 4      867950            46       Leicester            5.0             6.0
#
#    Total Shots  Blocked Shots  Shots insidebox  Shots outsidebox  Fouls  \
# 0           10            6.0              9.0               1.0     16
# 1            9            4.0              7.0               2.0      7
# 2            7            2.0              6.0               1.0     18
# 3           12            3.0              7.0               5.0     13
# 4           14            3.0              5.0               9.0      6
#
#    Corner Kicks  Offsides Ball Possession  Yellow Cards  Red Cards  \
# ...
